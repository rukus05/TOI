# %%
excel_dict = {'1FA_FF-FMLA_Other Earnings': {100100: 52000.0,
                                100200: 52000.0,
                                100300: 52000.0,
                                100400: 60000.0,
                                200100: 60000.0,
                                200200: 60000.0,
                                300100: 60000.0,
                                300200: 60000.0,
                                300250: 60000.0,
                                300300: 60000.0,
                                300400: 60000.0,
                                300500: 60000.0,
                                400100: 52000.0,
                                700100: 60000.0,
                                700110: 60000.0,
                                700120: 60000.0,
                                700200: 60000.0,
                                700205: 60000.0,
                                700210: 60000.0,
                                700215: 60000.0,
                                700225: 60000.0,
                                700230: 60000.0,
                                700300: 60000.0,
                                700305: 60000.0,
                                700310: 60000.0,
                                700315: 60000.0,
                                700320: 60000.0,
                                700325: 60000.0,
                                700326: 60000.0,
                                700327: 60000.0,
                                700330: 60000.0,
                                700335: 60000.0,
                                700340: 60000.0,
                                700345: 60000.0,
                                700350: 60000.0,
                                700360: 60000.0,
                                701000: 60000.0,
                                701100: 60000.0,
                                701200: 60000.0,
                                701210: 60000.0,
                                702010: 60000.0,
                                702100: 60000.0,
                                702300: 60000.0,
                                702400: 60000.0,
                                702410: 60000.0,
                                702415: 60000.0,
                                702420: 60000.0,
                                703000: 60000.0,
                                704000: 60000.0,
                                704100: 60000.0,
                                704500: 60000.0,
                                705000: 60000.0,
                                705500: 60000.0,
                                705600: 60000.0,
                                'index': 2},
 '1FE_FF-PSL-EE_Other Earnings': {100100: 52000.0,
                                  100200: 52000.0,
                                  100300: 52000.0,
                                  100400: 60000.0,
                                  200100: 60000.0,
                                  200200: 60000.0,
                                  300100: 60000.0,
                                  300200: 60000.0,
                                  300250: 60000.0,
                                  300300: 60000.0,
                                  300400: 60000.0,
                                  300500: 60000.0,
                                  400100: 52000.0,
                                  700100: 60000.0,
                                  700110: 60000.0,
                                  700120: 60000.0,
                                  700200: 60000.0,
                                  700205: 60000.0,
                                  700210: 60000.0,
                                  700215: 60000.0,
                                  700225: 60000.0,
                                  700230: 60000.0,
                                  700300: 60000.0,
                                  700305: 60000.0,
                                  700310: 60000.0,
                                  700315: 60000.0,
                                  700320: 60000.0,
                                  700325: 60000.0,
                                  700326: 60000.0,
                                  700327: 60000.0,
                                  700330: 60000.0,
                                  700335: 60000.0,
                                  700340: 60000.0,
                                  700345: 60000.0,
                                  700350: 60000.0,
                                  700360: 60000.0,
                                  701000: 60000.0,
                                  701100: 60000.0,
                                  701200: 60000.0,
                                  701210: 60000.0,
                                  702010: 60000.0,
                                  702100: 60000.0,
                                  702300: 60000.0,
                                  702400: 60000.0,
                                  702410: 60000.0,
                                  702415: 60000.0,
                                  702420: 60000.0,
                                  703000: 60000.0,
                                  704000: 60000.0,
                                  704100: 60000.0,
                                  704500: 60000.0,
                                  705000: 60000.0,
                                  705500: 60000.0,
                                  705600: 60000.0,
                                  'index': 3},
 '1FF_FF-PSL-FAM_Other Earnings': {100100: 52000.0,
                                   100200: 52000.0,
                                   100300: 52000.0,
                                   100400: 60000.0,
                                   200100: 60000.0,
                                   200200: 60000.0,
                                   300100: 60000.0,
                                   300200: 60000.0,
                                   300250: 60000.0,
                                   300300: 60000.0,
                                   300400: 60000.0,
                                   300500: 60000.0,
                                   400100: 52000.0,
                                   700100: 60000.0,
                                   700110: 60000.0,
                                   700120: 60000.0,
                                   700200: 60000.0,
                                   700205: 60000.0,
                                   700210: 60000.0,
                                   700215: 60000.0,
                                   700225: 60000.0,
                                   700230: 60000.0,
                                   700300: 60000.0,
                                   700305: 60000.0,
                                   700310: 60000.0,
                                   700315: 60000.0,
                                   700320: 60000.0,
                                   700325: 60000.0,
                                   700326: 60000.0,
                                   700327: 60000.0,
                                   700330: 60000.0,
                                   700335: 60000.0,
                                   700340: 60000.0,
                                   700345: 60000.0,
                                   700350: 60000.0,
                                   700360: 60000.0,
                                   701000: 60000.0,
                                   701100: 60000.0,
                                   701200: 60000.0,
                                   701210: 60000.0,
                                   702010: 60000.0,
                                   702100: 60000.0,
                                   702300: 60000.0,
                                   702400: 60000.0,
                                   702410: 60000.0,
                                   702415: 60000.0,
                                   702420: 60000.0,
                                   703000: 60000.0,
                                   704000: 60000.0,
                                   704100: 60000.0,
                                   704500: 60000.0,
                                   705000: 60000.0,
                                   705500: 60000.0,
                                   705600: 60000.0,
                                   'index': 4},
 '1FM_HLTH-FMLA CR_Memo': {100100: 0.0,
                           100200: 0.0,
                           100300: 0.0,
                           100400: 0.0,
                           200100: 0.0,
                           200200: 0.0,
                           300100: 0.0,
                           300200: 0.0,
                           300250: 0.0,
                           300300: 0.0,
                           300400: 0.0,
                           300500: 0.0,
                           400100: 0.0,
                           700100: 0.0,
                           700110: 0.0,
                           700120: 0.0,
                           700200: 0.0,
                           700205: 0.0,
                           700210: 0.0,
                           700215: 0.0,
                           700225: 0.0,
                           700230: 0.0,
                           700300: 0.0,
                           700305: 0.0,
                           700310: 0.0,
                           700315: 0.0,
                           700320: 0.0,
                           700325: 0.0,
                           700326: 0.0,
                           700327: 0.0,
                           700330: 0.0,
                           700335: 0.0,
                           700340: 0.0,
                           700345: 0.0,
                           700350: 0.0,
                           700360: 0.0,
                           701000: 0.0,
                           701100: 0.0,
                           701200: 0.0,
                           701210: 0.0,
                           702010: 0.0,
                           702100: 0.0,
                           702300: 0.0,
                           702400: 0.0,
                           702410: 0.0,
                           702415: 0.0,
                           702420: 0.0,
                           703000: 0.0,
                           704000: 0.0,
                           704100: 0.0,
                           704500: 0.0,
                           705000: 0.0,
                           705500: 0.0,
                           705600: 0.0,
                           'index': 145},
 '1HC_HLTH-PSL CR_Memo': {100100: 0.0,
                          100200: 0.0,
                          100300: 0.0,
                          100400: 0.0,
                          200100: 0.0,
                          200200: 0.0,
                          300100: 0.0,
                          300200: 0.0,
                          300250: 0.0,
                          300300: 0.0,
                          300400: 0.0,
                          300500: 0.0,
                          400100: 0.0,
                          700100: 0.0,
                          700110: 0.0,
                          700120: 0.0,
                          700200: 0.0,
                          700205: 0.0,
                          700210: 0.0,
                          700215: 0.0,
                          700225: 0.0,
                          700230: 0.0,
                          700300: 0.0,
                          700305: 0.0,
                          700310: 0.0,
                          700315: 0.0,
                          700320: 0.0,
                          700325: 0.0,
                          700326: 0.0,
                          700327: 0.0,
                          700330: 0.0,
                          700335: 0.0,
                          700340: 0.0,
                          700345: 0.0,
                          700350: 0.0,
                          700360: 0.0,
                          701000: 0.0,
                          701100: 0.0,
                          701200: 0.0,
                          701210: 0.0,
                          702010: 0.0,
                          702100: 0.0,
                          702300: 0.0,
                          702400: 0.0,
                          702410: 0.0,
                          702415: 0.0,
                          702420: 0.0,
                          703000: 0.0,
                          704000: 0.0,
                          704100: 0.0,
                          704500: 0.0,
                          705000: 0.0,
                          705500: 0.0,
                          705600: 0.0,
                          'index': 146}}

# %%
print(excel_dict)
# Out:
# {'1FA_FF-FMLA_Other Earnings': {100100: 52000.0, 100200: 52000.0, 100300: 52000.0, 100400: 60000.0, 200100: 60000.0, 200200: 60000.0, 300100: 60000.0, 300200: 60000.0, 300250: 60000.0, 300300: 60000.0, 300400: 60000.0, 300500: 60000.0, 400100: 52000.0, 700100: 60000.0, 700110: 60000.0, 700120: 60000.0, 700200: 60000.0, 700205: 60000.0, 700210: 60000.0, 700215: 60000.0, 700225: 60000.0, 700230: 60000.0, 700300: 60000.0, 700305: 60000.0, 700310: 60000.0, 700315: 60000.0, 700320: 60000.0, 700325: 60000.0, 700326: 60000.0, 700327: 60000.0, 700330: 60000.0, 700335: 60000.0, 700340: 60000.0, 700345: 60000.0, 700350: 60000.0, 700360: 60000.0, 701000: 60000.0, 701100: 60000.0, 701200: 60000.0, 701210: 60000.0, 702010: 60000.0, 702100: 60000.0, 702300: 60000.0, 702400: 60000.0, 702410: 60000.0, 702415: 60000.0, 702420: 60000.0, 703000: 60000.0, 704000: 60000.0, 704100: 60000.0, 704500: 60000.0, 705000: 60000.0, 705500: 60000.0, 705600: 60000.0, 'index': 2}, '1FE_FF-PSL-EE_Other Earnings': {10
# ...

# %%
kl = list(excel_dict.keys())
print(kl[3])
# Out:
# 1FM_HLTH-FMLA CR_Memo

# %%
print(excel_dict['1FE_FF-PSL-EE_Other Earnings'][100100])
# Out:
# 52000.0

# %%
i = '1HC_HLTH-PSL CR_Memo'
if i in excel_dict and excel_dict[i][100200] == 0.0:
    print(i)
# Out:
# 1HC_HLTH-PSL CR_Memo
